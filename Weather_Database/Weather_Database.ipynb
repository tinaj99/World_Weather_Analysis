# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#print(*cities, sep = "\n")
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=67ba61788e2a1e588b05e9f64206f82c

# %%
# Import the time library and the datetime module from the datetime library 
import time
#from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    print(set_count)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.        
        city_lat = round(city_weather["coord"]["lat"],2)
        city_lng = round(city_weather["coord"]["lon"],2)
        city_currentdesc = city_weather["weather"][0]["description"]
        city_max_temp = round(city_weather["main"]["temp_max"],2)
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = round(city_weather["wind"]["speed"],2)
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_currentdesc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# 1
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# 1
# Processing Record 2 of Set 1 | samusu
# City not found. Skipping...
# 1
# Processing Record 3 of Set 1 | butaritari
# 1
# Processing Record 4 of Set 1 | cape town
# 1
# Processing Record 5 of Set 1 | sentyabrskiy
# City not found. Skipping...
# 1
# Processing Record 6 of Set 1 | atuona
# 1
# Processing Record 7 of Set 1 | bluff
# 1
# Processing Record 8 of Set 1 | tuktoyaktuk
# 1
# Processing Record 9 of Set 1 | kapaa
# 1
# Processing Record 10 of Set 1 | panalingaan
# 1
# Processing Record 11 of Set 1 | albany
# 1
# Processing Record 12 of Set 1 | vaini
# 1
# Processing Record 13 of Set 1 | bow island
# 1
# Processing Record 14 of Set 1 | agadez
# 1
# Processing Record 15 of Set 1 | saleaula
# City not found. Skipping...
# 1
# Processing Record 16 of Set 1 | port elizabeth
# 1
# Processing Record 17 of Set 1 | kaeo
# 1
# Processing Record 18 of Set 1 | victoria
# 1
# Processing Record 19 of Set 1 | taburi
# City not found. Skipping...
# 1
# Processing Record 20 of Set 1 | thompson
# 1
# Processing Record 21 of Set 1 | busselton
# 1
# Processing Record 22 of Set 1 | rikitea
# 1
# Processing Record 23 of Set 1 | codrington
# 1
# Processing Record 24 of Set 1 | vidim
# 1
# Processing Record 25 of Set 1 | kaitangata
# 1
# Processing Record 26 of Set 1 | lata
# 1
# Processing Record 27 of Set 1 | provideniya
# 1
# Processing Record 28 of Set 1 | esperance
# 1
# Processing Record 29 of Set 1 | paraisopolis
# 1
# Processing Record 30 of Set 1 | broken hill
# 1
# Processing Record 31 of Set 1 | nabire
# 1
# Processing Record 32 of Set 1 | soverato
# 1
# Processing Record 33 of Set 1 | dunedin
# 1
# Processing Record 34 of Set 1 | jamestown
# 1
# Processing Record 35 of Set 1 | saint-philippe
# 1
# Processing Record 36 of Set 1 | punta arenas
# 1
# Processing Record 37 of Set 1 | mataura
# 1
# Processing Record 38 of Set 1 | ponta do sol
# 1
# Processing Record 39 of Set 1 | vila velha
# 1
# Processing Record 40 of Set 1 | hovd
# 1
# Processing Record 41 of Set 1 | fukue
# 1
# Processing Record 42 of Set 1 | las vegas
# 1
# Processing Record 43 of Set 1 | tevaitoa
# 1
# Processing Record 44 of Set 1 | georgetown
# 1
# Processing Record 45 of Set 1 | hermanus
# 1
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# 1
# Processing Record 47 of Set 1 | bredasdorp
# 1
# Processing Record 48 of Set 1 | ushuaia
# 1
# Processing Record 49 of Set 1 | fortuna foothills
# 1
# Processing Record 50 of Set 1 | norman wells
# 2
# Processing Record 1 of Set 2 | cottonwood
# 2
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# 2
# Processing Record 3 of Set 2 | sambava
# 2
# Processing Record 4 of Set 2 | boden
# 2
# Processing Record 5 of Set 2 | burica
# City not found. Skipping...
# 2
# Processing Record 6 of Set 2 | yellowknife
# 2
# Processing Record 7 of Set 2 | caldwell
# 2
# Processing Record 8 of Set 2 | dikson
# 2
# Processing Record 9 of Set 2 | cayenne
# 2
# Processing Record 10 of Set 2 | saint-pierre
# 2
# Processing Record 11 of Set 2 | bathsheba
# 2
# Processing Record 12 of Set 2 | salalah
# 2
# Processing Record 13 of Set 2 | quelimane
# 2
# Processing Record 14 of Set 2 | carutapera
# 2
# Processing Record 15 of Set 2 | tarauaca
# 2
# Processing Record 16 of Set 2 | ancud
# 2
# Processing Record 17 of Set 2 | utiroa
# City not found. Skipping...
# 2
# Processing Record 18 of Set 2 | new norfolk
# 2
# Processing Record 19 of Set 2 | avarua
# 2
# Processing Record 20 of Set 2 | luganville
# 2
# Processing Record 21 of Set 2 | mahebourg
# 2
# Processing Record 22 of Set 2 | namatanai
# 2
# Processing Record 23 of Set 2 | diapaga
# 2
# Processing Record 24 of Set 2 | ilulissat
# 2
# Processing Record 25 of Set 2 | skalistyy
# City not found. Skipping...
# 2
# Processing Record 26 of Set 2 | srednekolymsk
# 2
# Processing Record 27 of Set 2 | tumannyy
# City not found. Skipping...
# 2
# Processing Record 28 of Set 2 | balmedie
# 2
# Processing Record 29 of Set 2 | upernavik
# 2
# Processing Record 30 of Set 2 | raudeberg
# 2
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# 2
# Processing Record 32 of Set 2 | azogues
# 2
# Processing Record 33 of Set 2 | ouadda
# 2
# Processing Record 34 of Set 2 | berdigestyakh
# 2
# Processing Record 35 of Set 2 | pochutla
# 2
# Processing Record 36 of Set 2 | clyde river
# 2
# Processing Record 37 of Set 2 | saint george
# 2
# Processing Record 38 of Set 2 | hamilton
# 2
# Processing Record 39 of Set 2 | porto novo
# 2
# Processing Record 40 of Set 2 | longyearbyen
# 2
# Processing Record 41 of Set 2 | kruisfontein
# 2
# Processing Record 42 of Set 2 | san quintin
# 2
# Processing Record 43 of Set 2 | lompoc
# 2
# Processing Record 44 of Set 2 | katsuura
# 2
# Processing Record 45 of Set 2 | lebu
# 2
# Processing Record 46 of Set 2 | santa isabel
# 2
# Processing Record 47 of Set 2 | sao jose da coroa grande
# 2
# Processing Record 48 of Set 2 | touros
# 2
# Processing Record 49 of Set 2 | hobart
# 2
# Processing Record 50 of Set 2 | praya
# 3
# Processing Record 1 of Set 3 | kavaratti
# 3
# Processing Record 2 of Set 3 | barrow
# 3
# Processing Record 3 of Set 3 | bengkulu
# 3
# Processing Record 4 of Set 3 | port hawkesbury
# 3
# Processing Record 5 of Set 3 | olafsvik
# 3
# Processing Record 6 of Set 3 | aykhal
# 3
# Processing Record 7 of Set 3 | amahai
# 3
# Processing Record 8 of Set 3 | mandurah
# 3
# Processing Record 9 of Set 3 | titlagarh
# 3
# Processing Record 10 of Set 3 | salamiyah
# 3
# Processing Record 11 of Set 3 | khatanga
# 3
# Processing Record 12 of Set 3 | bouna
# 3
# Processing Record 13 of Set 3 | vanimo
# 3
# Processing Record 14 of Set 3 | tual
# 3
# Processing Record 15 of Set 3 | myitkyina
# 3
# Processing Record 16 of Set 3 | halalo
# City not found. Skipping...
# 3
# Processing Record 17 of Set 3 | suntar
# 3
# Processing Record 18 of Set 3 | ketchikan
# 3
# Processing Record 19 of Set 3 | asahi
# 3
# Processing Record 20 of Set 3 | mabaruma
# 3
# Processing Record 21 of Set 3 | qaanaaq
# 3
# Processing Record 22 of Set 3 | ribeira grande
# 3
# Processing Record 23 of Set 3 | mar del plata
# 3
# Processing Record 24 of Set 3 | port alfred
# 3
# Processing Record 25 of Set 3 | dicabisagan
# 3
# Processing Record 26 of Set 3 | porterville
# 3
# Processing Record 27 of Set 3 | rosarito
# 3
# Processing Record 28 of Set 3 | aksarka
# 3
# Processing Record 29 of Set 3 | tautira
# 3
# Processing Record 30 of Set 3 | zolotkovo
# 3
# Processing Record 31 of Set 3 | oranjemund
# 3
# Processing Record 32 of Set 3 | terrace
# 3
# Processing Record 33 of Set 3 | los llanos de aridane
# 3
# Processing Record 34 of Set 3 | voznesenye
# 3
# Processing Record 35 of Set 3 | marawi
# 3
# Processing Record 36 of Set 3 | nikolskoye
# 3
# Processing Record 37 of Set 3 | chicama
# 3
# Processing Record 38 of Set 3 | te anau
# 3
# Processing Record 39 of Set 3 | coos bay
# 3
# Processing Record 40 of Set 3 | galiwinku
# City not found. Skipping...
# 3
# Processing Record 41 of Set 3 | cidreira
# 3
# Processing Record 42 of Set 3 | colac
# 3
# Processing Record 43 of Set 3 | faanui
# 3
# Processing Record 44 of Set 3 | gobabis
# 3
# Processing Record 45 of Set 3 | frankfort
# 3
# Processing Record 46 of Set 3 | ebbs
# 3
# Processing Record 47 of Set 3 | romitan
# 3
# Processing Record 48 of Set 3 | arraial do cabo
# 3
# Processing Record 49 of Set 3 | arman
# 3
# Processing Record 50 of Set 3 | saskylakh
# 4
# Processing Record 1 of Set 4 | geraldton
# 4
# Processing Record 2 of Set 4 | adrar
# 4
# Processing Record 3 of Set 4 | baiyin
# 4
# Processing Record 4 of Set 4 | were ilu
# 4
# Processing Record 5 of Set 4 | antofagasta
# 4
# Processing Record 6 of Set 4 | tasiilaq
# 4
# Processing Record 7 of Set 4 | channel-port aux basques
# 4
# Processing Record 8 of Set 4 | jibuti
# 4
# Processing Record 9 of Set 4 | lagoa
# 4
# Processing Record 10 of Set 4 | karratha
# 4
# Processing Record 11 of Set 4 | tuy hoa
# 4
# Processing Record 12 of Set 4 | tsihombe
# City not found. Skipping...
# 4
# Processing Record 13 of Set 4 | rome
# 4
# Processing Record 14 of Set 4 | aswan
# 4
# Processing Record 15 of Set 4 | kahului
# 4
# Processing Record 16 of Set 4 | udachnyy
# 4
# Processing Record 17 of Set 4 | henties bay
# 4
# Processing Record 18 of Set 4 | ovsyanka
# 4
# Processing Record 19 of Set 4 | mount gambier
# 4
# Processing Record 20 of Set 4 | carnarvon
# 4
# Processing Record 21 of Set 4 | popondetta
# 4
# Processing Record 22 of Set 4 | hyeres
# 4
# Processing Record 23 of Set 4 | skibbereen
# 4
# Processing Record 24 of Set 4 | haldia
# 4
# Processing Record 25 of Set 4 | tongliao
# 4
# Processing Record 26 of Set 4 | severo-kurilsk
# 4
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# 4
# Processing Record 28 of Set 4 | pisco
# 4
# Processing Record 29 of Set 4 | cherskiy
# 4
# Processing Record 30 of Set 4 | boli
# 4
# Processing Record 31 of Set 4 | springdale
# 4
# Processing Record 32 of Set 4 | acajutla
# 4
# Processing Record 33 of Set 4 | aborlan
# 4
# Processing Record 34 of Set 4 | boyolangu
# 4
# Processing Record 35 of Set 4 | barcelona
# 4
# Processing Record 36 of Set 4 | kisangani
# 4
# Processing Record 37 of Set 4 | tubruq
# City not found. Skipping...
# 4
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# 4
# Processing Record 39 of Set 4 | kodiak
# 4
# Processing Record 40 of Set 4 | noyabrsk
# 4
# Processing Record 41 of Set 4 | karkaralinsk
# City not found. Skipping...
# 4
# Processing Record 42 of Set 4 | kerema
# 4
# Processing Record 43 of Set 4 | lere
# 4
# Processing Record 44 of Set 4 | dukat
# 4
# Processing Record 45 of Set 4 | port-gentil
# 4
# Processing Record 46 of Set 4 | mocambique
# City not found. Skipping...
# 4
# Processing Record 47 of Set 4 | juneau
# 4
# Processing Record 48 of Set 4 | buala
# 4
# Processing Record 49 of Set 4 | kavieng
# 4
# Processing Record 50 of Set 4 | gamba
# 5
# Processing Record 1 of Set 5 | fastiv
# 5
# Processing Record 2 of Set 5 | vao
# 5
# Processing Record 3 of Set 5 | castro
# 5
# Processing Record 4 of Set 5 | les escoumins
# 5
# Processing Record 5 of Set 5 | ahipara
# 5
# Processing Record 6 of Set 5 | metro
# 5
# Processing Record 7 of Set 5 | tiznit
# 5
# Processing Record 8 of Set 5 | rungata
# City not found. Skipping...
# 5
# Processing Record 9 of Set 5 | wukari
# 5
# Processing Record 10 of Set 5 | bolungarvik
# City not found. Skipping...
# 5
# Processing Record 11 of Set 5 | boa vista
# 5
# Processing Record 12 of Set 5 | puerto ayora
# 5
# Processing Record 13 of Set 5 | tala
# 5
# Processing Record 14 of Set 5 | tessalit
# 5
# Processing Record 15 of Set 5 | sulangan
# 5
# Processing Record 16 of Set 5 | oistins
# 5
# Processing Record 17 of Set 5 | hilo
# 5
# Processing Record 18 of Set 5 | port blair
# 5
# Processing Record 19 of Set 5 | mokhsogollokh
# 5
# Processing Record 20 of Set 5 | biak
# 5
# Processing Record 21 of Set 5 | coihaique
# 5
# Processing Record 22 of Set 5 | fort nelson
# 5
# Processing Record 23 of Set 5 | cap malheureux
# 5
# Processing Record 24 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# 5
# Processing Record 25 of Set 5 | guarapari
# 5
# Processing Record 26 of Set 5 | harper
# 5
# Processing Record 27 of Set 5 | dengzhou
# 5
# Processing Record 28 of Set 5 | dekar
# 5
# Processing Record 29 of Set 5 | avera
# 5
# Processing Record 30 of Set 5 | westport
# 5
# Processing Record 31 of Set 5 | hualmay
# 5
# Processing Record 32 of Set 5 | kalmunai
# 5
# Processing Record 33 of Set 5 | caravelas
# 5
# Processing Record 34 of Set 5 | pandan
# 5
# Processing Record 35 of Set 5 | sao joao da barra
# 5
# Processing Record 36 of Set 5 | lovozero
# 5
# Processing Record 37 of Set 5 | windsor
# 5
# Processing Record 38 of Set 5 | bosansko grahovo
# 5
# Processing Record 39 of Set 5 | iqaluit
# 5
# Processing Record 40 of Set 5 | faya
# 5
# Processing Record 41 of Set 5 | kralendijk
# 5
# Processing Record 42 of Set 5 | torbay
# 5
# Processing Record 43 of Set 5 | trincomalee
# 5
# Processing Record 44 of Set 5 | kamenka
# 5
# Processing Record 45 of Set 5 | thurso
# 5
# Processing Record 46 of Set 5 | kirakira
# 5
# Processing Record 47 of Set 5 | kpandae
# 5
# Processing Record 48 of Set 5 | fortuna
# 5
# Processing Record 49 of Set 5 | hambantota
# 5
# Processing Record 50 of Set 5 | lagdo
# 6
# Processing Record 1 of Set 6 | alice springs
# 6
# Processing Record 2 of Set 6 | muscat
# 6
# Processing Record 3 of Set 6 | kodinsk
# 6
# Processing Record 4 of Set 6 | luderitz
# 6
# Processing Record 5 of Set 6 | pierre
# 6
# Processing Record 6 of Set 6 | riyadh
# 6
# Processing Record 7 of Set 6 | kisanga
# 6
# Processing Record 8 of Set 6 | moji-mirim
# City not found. Skipping...
# 6
# Processing Record 9 of Set 6 | albi
# 6
# Processing Record 10 of Set 6 | wanning
# 6
# Processing Record 11 of Set 6 | barabai
# 6
# Processing Record 12 of Set 6 | taltal
# 6
# Processing Record 13 of Set 6 | brae
# 6
# Processing Record 14 of Set 6 | sao joaquim
# 6
# Processing Record 15 of Set 6 | tsienyane
# City not found. Skipping...
# 6
# Processing Record 16 of Set 6 | hithadhoo
# 6
# Processing Record 17 of Set 6 | khani
# 6
# Processing Record 18 of Set 6 | bethel
# 6
# Processing Record 19 of Set 6 | airai
# 6
# Processing Record 20 of Set 6 | belovo
# 6
# Processing Record 21 of Set 6 | shirokiy
# 6
# Processing Record 22 of Set 6 | domoni
# 6
# Processing Record 23 of Set 6 | vieques
# 6
# Processing Record 24 of Set 6 | palabuhanratu
# City not found. Skipping...
# 6
# Processing Record 25 of Set 6 | yeppoon
# 6
# Processing Record 26 of Set 6 | guadalajara
# 6
# Processing Record 27 of Set 6 | taksimo
# 6
# Processing Record 28 of Set 6 | vilyuysk
# 6
# Processing Record 29 of Set 6 | mercedes
# 6
# Processing Record 30 of Set 6 | ponta delgada
# 6
# Processing Record 31 of Set 6 | moctezuma
# 6
# Processing Record 32 of Set 6 | bouar
# 6
# Processing Record 33 of Set 6 | herat
# 6
# Processing Record 34 of Set 6 | suez
# 6
# Processing Record 35 of Set 6 | lasa
# 6
# Processing Record 36 of Set 6 | ingham
# 6
# Processing Record 37 of Set 6 | east london
# 6
# Processing Record 38 of Set 6 | lafia
# 6
# Processing Record 39 of Set 6 | nome
# 6
# Processing Record 40 of Set 6 | tiksi
# 6
# Processing Record 41 of Set 6 | bafoulabe
# 6
# Processing Record 42 of Set 6 | bud
# 6
# Processing Record 43 of Set 6 | mwense
# 6
# Processing Record 44 of Set 6 | black river
# 6
# Processing Record 45 of Set 6 | marcona
# City not found. Skipping...
# 6
# Processing Record 46 of Set 6 | nuuk
# 6
# Processing Record 47 of Set 6 | struga
# 6
# Processing Record 48 of Set 6 | ariquemes
# 6
# Processing Record 49 of Set 6 | kommunisticheskiy
# 6
# Processing Record 50 of Set 6 | khonuu
# City not found. Skipping...
# 7
# Processing Record 1 of Set 7 | waipawa
# 7
# Processing Record 2 of Set 7 | mehran
# 7
# Processing Record 3 of Set 7 | chara
# 7
# Processing Record 4 of Set 7 | gulshat
# City not found. Skipping...
# 7
# Processing Record 5 of Set 7 | isangel
# 7
# Processing Record 6 of Set 7 | pacific grove
# 7
# Processing Record 7 of Set 7 | zlatoustovsk
# City not found. Skipping...
# 7
# Processing Record 8 of Set 7 | tobias barreto
# 7
# Processing Record 9 of Set 7 | rock sound
# 7
# Processing Record 10 of Set 7 | aksay
# 7
# Processing Record 11 of Set 7 | half moon bay
# 7
# Processing Record 12 of Set 7 | angelholm
# City not found. Skipping...
# 7
# Processing Record 13 of Set 7 | narsaq
# 7
# Processing Record 14 of Set 7 | praia
# 7
# Processing Record 15 of Set 7 | pasir gudang
# 7
# Processing Record 16 of Set 7 | kabare
# 7
# Processing Record 17 of Set 7 | chisec
# 7
# Processing Record 18 of Set 7 | porto-vecchio
# 7
# Processing Record 19 of Set 7 | tucurui
# 7
# Processing Record 20 of Set 7 | saint-raymond
# 7
# Processing Record 21 of Set 7 | belaya gora
# 7
# Processing Record 22 of Set 7 | guerrero negro
# 7
# Processing Record 23 of Set 7 | rawson
# 7
# Processing Record 24 of Set 7 | magrath
# 7
# Processing Record 25 of Set 7 | sur
# 7
# Processing Record 26 of Set 7 | jinchang
# 7
# Processing Record 27 of Set 7 | davila
# 7
# Processing Record 28 of Set 7 | limbang
# 7
# Processing Record 29 of Set 7 | bilibino
# 7
# Processing Record 30 of Set 7 | soyo
# 7
# Processing Record 31 of Set 7 | niquelandia
# 7
# Processing Record 32 of Set 7 | maceio
# 7
# Processing Record 33 of Set 7 | cockburn town
# 7
# Processing Record 34 of Set 7 | mabamba
# 7
# Processing Record 35 of Set 7 | banff
# 7
# Processing Record 36 of Set 7 | ambilobe
# 7
# Processing Record 37 of Set 7 | nanortalik
# 7
# Processing Record 38 of Set 7 | zlitan
# 7
# Processing Record 39 of Set 7 | longlac
# City not found. Skipping...
# 7
# Processing Record 40 of Set 7 | nabannagan
# 7
# Processing Record 41 of Set 7 | eskilstuna
# 7
# Processing Record 42 of Set 7 | malazgirt
# 7
# Processing Record 43 of Set 7 | muros
# 7
# Processing Record 44 of Set 7 | atar
# 7
# Processing Record 45 of Set 7 | gander
# 7
# Processing Record 46 of Set 7 | sampit
# 7
# Processing Record 47 of Set 7 | kuah
# 7
# Processing Record 48 of Set 7 | constitucion
# 7
# Processing Record 49 of Set 7 | petropavlovsk-kamchatskiy
# 7
# Processing Record 50 of Set 7 | kananga
# 8
# Processing Record 1 of Set 8 | goderich
# 8
# Processing Record 2 of Set 8 | port lincoln
# 8
# Processing Record 3 of Set 8 | weligama
# 8
# Processing Record 4 of Set 8 | hami
# 8
# Processing Record 5 of Set 8 | amderma
# City not found. Skipping...
# 8
# Processing Record 6 of Set 8 | miles city
# 8
# Processing Record 7 of Set 8 | torit
# 8
# Processing Record 8 of Set 8 | charlestown
# 8
# Processing Record 9 of Set 8 | makakilo city
# 8
# Processing Record 10 of Set 8 | wahran
# City not found. Skipping...
# 8
# Processing Record 11 of Set 8 | assiniboia
# 8
# Processing Record 12 of Set 8 | astana
# 8
# Processing Record 13 of Set 8 | manono
# 8
# Processing Record 14 of Set 8 | west lorne
# 8
# Processing Record 15 of Set 8 | malwan
# City not found. Skipping...
# 8
# Processing Record 16 of Set 8 | dagana
# 8
# Processing Record 17 of Set 8 | teguise
# 8
# Processing Record 18 of Set 8 | lorengau
# 8
# Processing Record 19 of Set 8 | saldanha
# 8
# Processing Record 20 of Set 8 | beringovskiy
# 8
# Processing Record 21 of Set 8 | mahajanga
# 8
# Processing Record 22 of Set 8 | sao gabriel da cachoeira
# 8
# Processing Record 23 of Set 8 | zhanatas
# City not found. Skipping...
# 8
# Processing Record 24 of Set 8 | beyla
# 8
# Processing Record 25 of Set 8 | georgiyevka
# 8
# Processing Record 26 of Set 8 | yar-sale
# 8
# Processing Record 27 of Set 8 | ostrovnoy
# 8
# Processing Record 28 of Set 8 | ternate
# 8
# Processing Record 29 of Set 8 | komsomolskiy
# 8
# Processing Record 30 of Set 8 | tarko-sale
# 8
# Processing Record 31 of Set 8 | honiara
# 8
# Processing Record 32 of Set 8 | arlit
# 8
# Processing Record 33 of Set 8 | qaqortoq
# 8
# Processing Record 34 of Set 8 | elayirampannai
# 8
# Processing Record 35 of Set 8 | portland
# 8
# Processing Record 36 of Set 8 | husavik
# 8
# Processing Record 37 of Set 8 | cabedelo
# 8
# Processing Record 38 of Set 8 | talnakh
# 8
# Processing Record 39 of Set 8 | sao filipe
# 8
# Processing Record 40 of Set 8 | ust-nera
# 8
# Processing Record 41 of Set 8 | jishou
# 8
# Processing Record 42 of Set 8 | port antonio
# 8
# Processing Record 43 of Set 8 | sola
# 8
# Processing Record 44 of Set 8 | joao pinheiro
# 8
# Processing Record 45 of Set 8 | maumere
# 8
# Processing Record 46 of Set 8 | ugoofaaru
# 8
# Processing Record 47 of Set 8 | ekangala
# 8
# Processing Record 48 of Set 8 | weinan
# 8
# Processing Record 49 of Set 8 | lucapa
# 8
# Processing Record 50 of Set 8 | baicheng
# 9
# Processing Record 1 of Set 9 | la ronge
# 9
# Processing Record 2 of Set 9 | sorvag
# City not found. Skipping...
# 9
# Processing Record 3 of Set 9 | massakory
# 9
# Processing Record 4 of Set 9 | kigorobya
# 9
# Processing Record 5 of Set 9 | vardo
# 9
# Processing Record 6 of Set 9 | teya
# 9
# Processing Record 7 of Set 9 | dakar
# 9
# Processing Record 8 of Set 9 | gold coast
# 9
# Processing Record 9 of Set 9 | bozdar
# 9
# Processing Record 10 of Set 9 | ishigaki
# 9
# Processing Record 11 of Set 9 | vila franca do campo
# 9
# Processing Record 12 of Set 9 | dire
# 9
# Processing Record 13 of Set 9 | formoso do araguaia
# City not found. Skipping...
# 9
# Processing Record 14 of Set 9 | dzhusaly
# City not found. Skipping...
# 9
# Processing Record 15 of Set 9 | peringat
# 9
# Processing Record 16 of Set 9 | karpogory
# 9
# Processing Record 17 of Set 9 | sitka
# 9
# Processing Record 18 of Set 9 | madang
# 9
# Processing Record 19 of Set 9 | erenhot
# 9
# Processing Record 20 of Set 9 | tura
# 9
# Processing Record 21 of Set 9 | fairbanks
# 9
# Processing Record 22 of Set 9 | yuanping
# 9
# Processing Record 23 of Set 9 | zvecka
# 9
# Processing Record 24 of Set 9 | mahadday weyne
# City not found. Skipping...
# 9
# Processing Record 25 of Set 9 | marinette
# 9
# Processing Record 26 of Set 9 | xicotencatl
# 9
# Processing Record 27 of Set 9 | abu kamal
# 9
# Processing Record 28 of Set 9 | dipkarpaz
# City not found. Skipping...
# 9
# Processing Record 29 of Set 9 | berezovyy
# 9
# Processing Record 30 of Set 9 | yerbogachen
# 9
# Processing Record 31 of Set 9 | grindavik
# 9
# Processing Record 32 of Set 9 | asyut
# 9
# Processing Record 33 of Set 9 | santa vitoria do palmar
# 9
# Processing Record 34 of Set 9 | sovetskiy
# 9
# Processing Record 35 of Set 9 | salisbury
# 9
# Processing Record 36 of Set 9 | toora-khem
# 9
# Processing Record 37 of Set 9 | banon
# 9
# Processing Record 38 of Set 9 | puerto escondido
# 9
# Processing Record 39 of Set 9 | cochrane
# 9
# Processing Record 40 of Set 9 | ijaki
# City not found. Skipping...
# 9
# Processing Record 41 of Set 9 | zhangye
# 9
# Processing Record 42 of Set 9 | okha
# 9
# Processing Record 43 of Set 9 | urucara
# 9
# Processing Record 44 of Set 9 | umzimvubu
# City not found. Skipping...
# 9
# Processing Record 45 of Set 9 | malie
# 9
# Processing Record 46 of Set 9 | ballina
# 9
# Processing Record 47 of Set 9 | novosergiyevka
# 9
# Processing Record 48 of Set 9 | xiongzhou
# 9
# Processing Record 49 of Set 9 | saint-louis
# 9
# Processing Record 50 of Set 9 | west bay
# 10
# Processing Record 1 of Set 10 | araouane
# 10
# Processing Record 2 of Set 10 | brenham
# 10
# Processing Record 3 of Set 10 | kikwit
# 10
# Processing Record 4 of Set 10 | watertown
# 10
# Processing Record 5 of Set 10 | olhao
# 10
# Processing Record 6 of Set 10 | san patricio
# 10
# Processing Record 7 of Set 10 | koungheul
# 10
# Processing Record 8 of Set 10 | jaipur hat
# City not found. Skipping...
# 10
# Processing Record 9 of Set 10 | sioux falls
# 10
# Processing Record 10 of Set 10 | goma
# 10
# Processing Record 11 of Set 10 | paka
# 10
# Processing Record 12 of Set 10 | clinton
# 10
# Processing Record 13 of Set 10 | pemba
# 10
# Processing Record 14 of Set 10 | babaeski
# 10
# Processing Record 15 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# 10
# Processing Record 16 of Set 10 | ondjiva
# 10
# Processing Record 17 of Set 10 | balabac
# 10
# Processing Record 18 of Set 10 | sabha
# 10
# Processing Record 19 of Set 10 | akdepe
# 10
# Processing Record 20 of Set 10 | pemangkat
# 10
# Processing Record 21 of Set 10 | armizonskoye
# 10
# Processing Record 22 of Set 10 | greenwood
# 10
# Processing Record 23 of Set 10 | burnie
# 10
# Processing Record 24 of Set 10 | grand river south east
# City not found. Skipping...
# 10
# Processing Record 25 of Set 10 | berlevag
# 10
# Processing Record 26 of Set 10 | cozumel
# 10
# Processing Record 27 of Set 10 | vestmannaeyjar
# 10
# Processing Record 28 of Set 10 | stornoway
# 10
# Processing Record 29 of Set 10 | farah
# 10
# Processing Record 30 of Set 10 | cienfuegos
# 10
# Processing Record 31 of Set 10 | manta
# 10
# Processing Record 32 of Set 10 | cabo san lucas
# 10
# Processing Record 33 of Set 10 | deputatskiy
# 10
# Processing Record 34 of Set 10 | valparaiso
# 10
# Processing Record 35 of Set 10 | vanavara
# 10
# Processing Record 36 of Set 10 | westlock
# 10
# Processing Record 37 of Set 10 | tombouctou
# 10
# Processing Record 38 of Set 10 | savonlinna
# 10
# Processing Record 39 of Set 10 | galle
# 10
# Processing Record 40 of Set 10 | bababe
# City not found. Skipping...
# 10
# Processing Record 41 of Set 10 | wilmington
# 10
# Processing Record 42 of Set 10 | ilhabela
# 10
# Processing Record 43 of Set 10 | boca do acre
# 10
# Processing Record 44 of Set 10 | murygino
# 10
# Processing Record 45 of Set 10 | dobroye
# 10
# Processing Record 46 of Set 10 | sinnamary
# 10
# Processing Record 47 of Set 10 | svetlyy
# 10
# Processing Record 48 of Set 10 | barentsburg
# City not found. Skipping...
# 10
# Processing Record 49 of Set 10 | phulabani
# 10
# Processing Record 50 of Set 10 | naze
# 11
# Processing Record 1 of Set 11 | abu samrah
# 11
# Processing Record 2 of Set 11 | lindsay
# 11
# Processing Record 3 of Set 11 | hailar
# 11
# Processing Record 4 of Set 11 | mae sai
# 11
# Processing Record 5 of Set 11 | klaksvik
# 11
# Processing Record 6 of Set 11 | pucallpa
# 11
# Processing Record 7 of Set 11 | askino
# 11
# Processing Record 8 of Set 11 | mala
# 11
# Processing Record 9 of Set 11 | haines junction
# 11
# Processing Record 10 of Set 11 | bandarbeyla
# 11
# Processing Record 11 of Set 11 | tommot
# 11
# Processing Record 12 of Set 11 | aklavik
# 11
# Processing Record 13 of Set 11 | necochea
# 11
# Processing Record 14 of Set 11 | yarim
# 11
# Processing Record 15 of Set 11 | aksha
# 11
# Processing Record 16 of Set 11 | krasnoselkup
# 11
# Processing Record 17 of Set 11 | pevek
# 11
# Processing Record 18 of Set 11 | edgewater
# 11
# Processing Record 19 of Set 11 | port hedland
# 11
# Processing Record 20 of Set 11 | carauari
# 11
# Processing Record 21 of Set 11 | ibra
# 11
# Processing Record 22 of Set 11 | riviere-au-renard
# 11
# Processing Record 23 of Set 11 | samoded
# 11
# Processing Record 24 of Set 11 | quatre cocos
# 11
# Processing Record 25 of Set 11 | iberia
# 11
# Processing Record 26 of Set 11 | meulaboh
# 11
# Processing Record 27 of Set 11 | margate
# 11
# Processing Record 28 of Set 11 | mount isa
# 11
# Processing Record 29 of Set 11 | safaga
# 11
# Processing Record 30 of Set 11 | santiago
# 11
# Processing Record 31 of Set 11 | daxian
# City not found. Skipping...
# 11
# Processing Record 32 of Set 11 | flinders
# 11
# Processing Record 33 of Set 11 | huarmey
# 11
# Processing Record 34 of Set 11 | lolua
# City not found. Skipping...
# 11
# Processing Record 35 of Set 11 | chokurdakh
# 11
# Processing Record 36 of Set 11 | cedar city
# 11
# Processing Record 37 of Set 11 | veraval
# 11
# Processing Record 38 of Set 11 | alberton
# 11
# Processing Record 39 of Set 11 | kingman
# 11
# Processing Record 40 of Set 11 | rio gallegos
# 11
# Processing Record 41 of Set 11 | banda aceh
# 11
# Processing Record 42 of Set 11 | neuquen
# 11
# Processing Record 43 of Set 11 | bara
# 11
# Processing Record 44 of Set 11 | solenzo
# 11
# Processing Record 45 of Set 11 | ziro
# 11
# Processing Record 46 of Set 11 | sun city west
# 11
# Processing Record 47 of Set 11 | abiy adi
# City not found. Skipping...
# 11
# Processing Record 48 of Set 11 | dzhankoy
# 11
# Processing Record 49 of Set 11 | inuvik
# 11
# Processing Record 50 of Set 11 | chekhov
# 12
# Processing Record 1 of Set 12 | geilo
# 12
# Processing Record 2 of Set 12 | keuruu
# 12
# Processing Record 3 of Set 12 | egvekinot
# 12
# Processing Record 4 of Set 12 | dwarka
# 12
# Processing Record 5 of Set 12 | kyra
# 12
# Processing Record 6 of Set 12 | lawrence
# 12
# Processing Record 7 of Set 12 | viedma
# 12
# Processing Record 8 of Set 12 | chuy
# 12
# Processing Record 9 of Set 12 | atambua
# 12
# Processing Record 10 of Set 12 | karamay
# City not found. Skipping...
# 12
# Processing Record 11 of Set 12 | ngunguru
# 12
# Processing Record 12 of Set 12 | shenjiamen
# 12
# Processing Record 13 of Set 12 | nizwa
# 12
# Processing Record 14 of Set 12 | yumbo
# 12
# Processing Record 15 of Set 12 | ojinaga
# 12
# Processing Record 16 of Set 12 | seoul
# 12
# Processing Record 17 of Set 12 | montrose
# 12
# Processing Record 18 of Set 12 | nizhniy kuranakh
# 12
# Processing Record 19 of Set 12 | magdagachi
# 12
# Processing Record 20 of Set 12 | isoka
# 12
# Processing Record 21 of Set 12 | natal
# 12
# Processing Record 22 of Set 12 | zhigansk
# 12
# Processing Record 23 of Set 12 | altay
# 12
# Processing Record 24 of Set 12 | nha trang
# 12
# Processing Record 25 of Set 12 | gushikawa
# 12
# Processing Record 26 of Set 12 | novyye gorki
# 12
# Processing Record 27 of Set 12 | carballo
# 12
# Processing Record 28 of Set 12 | karamea
# City not found. Skipping...
# 12
# Processing Record 29 of Set 12 | remontnoye
# 12
# Processing Record 30 of Set 12 | revda
# 12
# Processing Record 31 of Set 12 | hirara
# 12
# Processing Record 32 of Set 12 | aberdeen
# 12
# Processing Record 33 of Set 12 | lesnoye
# 12
# Processing Record 34 of Set 12 | bhuj
# 12
# Processing Record 35 of Set 12 | turukhansk
# 12
# Processing Record 36 of Set 12 | kununurra
# 12
# Processing Record 37 of Set 12 | concepcion del oro
# 12
# Processing Record 38 of Set 12 | anadyr
# 12
# Processing Record 39 of Set 12 | longhua
# 12
# Processing Record 40 of Set 12 | bambous virieux
# 12
# Processing Record 41 of Set 12 | biltine
# 12
# Processing Record 42 of Set 12 | lisieux
# 12
# Processing Record 43 of Set 12 | milyutinskaya
# 12
# Processing Record 44 of Set 12 | hofn
# 12
# Processing Record 45 of Set 12 | agogo
# 12
# Processing Record 46 of Set 12 | nantucket
# 12
# Processing Record 47 of Set 12 | yara
# 12
# Processing Record 48 of Set 12 | santa fe
# 12
# Processing Record 49 of Set 12 | alpena
# 12
# Processing Record 50 of Set 12 | brigantine
# 13
# Processing Record 1 of Set 13 | amalapuram
# 13
# Processing Record 2 of Set 13 | buraydah
# 13
# Processing Record 3 of Set 13 | tezu
# 13
# Processing Record 4 of Set 13 | belen
# 13
# Processing Record 5 of Set 13 | iquique
# 13
# Processing Record 6 of Set 13 | puerto del rosario
# 13
# Processing Record 7 of Set 13 | osypenko
# 13
# Processing Record 8 of Set 13 | santa isabel do rio negro
# 13
# Processing Record 9 of Set 13 | dingle
# 13
# Processing Record 10 of Set 13 | college
# 13
# Processing Record 11 of Set 13 | booue
# 13
# Processing Record 12 of Set 13 | chapais
# 13
# Processing Record 13 of Set 13 | barahona
# 13
# Processing Record 14 of Set 13 | kropotkin
# 13
# Processing Record 15 of Set 13 | camacha
# 13
# Processing Record 16 of Set 13 | chegdomyn
# 13
# Processing Record 17 of Set 13 | gat
# 13
# Processing Record 18 of Set 13 | plouzane
# 13
# Processing Record 19 of Set 13 | rubiera
# 13
# Processing Record 20 of Set 13 | ituni
# City not found. Skipping...
# 13
# Processing Record 21 of Set 13 | taoudenni
# 13
# Processing Record 22 of Set 13 | shingu
# 13
# Processing Record 23 of Set 13 | sorland
# 13
# Processing Record 24 of Set 13 | itarema
# 13
# Processing Record 25 of Set 13 | kuche
# City not found. Skipping...
# 13
# Processing Record 26 of Set 13 | punta alta
# 13
# Processing Record 27 of Set 13 | zhezkazgan
# 13
# Processing Record 28 of Set 13 | prince rupert
# 13
# Processing Record 29 of Set 13 | peniche
# 13
# Processing Record 30 of Set 13 | ntoum
# 13
# Processing Record 31 of Set 13 | talcahuano
# 13
# Processing Record 32 of Set 13 | rovaniemi
# 13
# Processing Record 33 of Set 13 | tungkang
# City not found. Skipping...
# 13
# Processing Record 34 of Set 13 | assis
# 13
# Processing Record 35 of Set 13 | hay river
# 13
# Processing Record 36 of Set 13 | mandalgovi
# 13
# Processing Record 37 of Set 13 | acari
# 13
# Processing Record 38 of Set 13 | north las vegas
# 13
# Processing Record 39 of Set 13 | aflu
# City not found. Skipping...
# 13
# Processing Record 40 of Set 13 | umm kaddadah
# 13
# Processing Record 41 of Set 13 | acapulco
# 13
# Processing Record 42 of Set 13 | sangar
# 13
# Processing Record 43 of Set 13 | monrovia
# 13
# Processing Record 44 of Set 13 | tuatapere
# 13
# Processing Record 45 of Set 13 | mapimi
# 13
# Processing Record 46 of Set 13 | knysna
# 13
# Processing Record 47 of Set 13 | coquimbo
# 13
# Processing Record 48 of Set 13 | denpasar
# 13
# Processing Record 49 of Set 13 | vallenar
# 13
# Processing Record 50 of Set 13 | putai
# 14
# Processing Record 1 of Set 14 | padang
# 14
# Processing Record 2 of Set 14 | balezino
# 14
# Processing Record 3 of Set 14 | ishikawa
# 14
# Processing Record 4 of Set 14 | muisne
# 14
# Processing Record 5 of Set 14 | cotonou
# 14
# Processing Record 6 of Set 14 | arroyo grande
# 14
# Processing Record 7 of Set 14 | borba
# 14
# Processing Record 8 of Set 14 | lashio
# 14
# Processing Record 9 of Set 14 | takoradi
# 14
# Processing Record 10 of Set 14 | ranipur
# 14
# Processing Record 11 of Set 14 | senmonorom
# City not found. Skipping...
# 14
# Processing Record 12 of Set 14 | alyangula
# 14
# Processing Record 13 of Set 14 | san pedro
# 14
# Processing Record 14 of Set 14 | awjilah
# 14
# Processing Record 15 of Set 14 | asau
# 14
# Processing Record 16 of Set 14 | karpathos
# 14
# Processing Record 17 of Set 14 | diglur
# 14
# Processing Record 18 of Set 14 | lianzhou
# 14
# Processing Record 19 of Set 14 | porto walter
# 14
# Processing Record 20 of Set 14 | moissala
# 14
# Processing Record 21 of Set 14 | ambon
# 14
# Processing Record 22 of Set 14 | artyk
# City not found. Skipping...
# 14
# Processing Record 23 of Set 14 | uri
# 14
# Processing Record 24 of Set 14 | korla
# 14
# Processing Record 25 of Set 14 | shahr-e babak
# 14
# Processing Record 26 of Set 14 | kozienice
# 14
# Processing Record 27 of Set 14 | searcy
# 14
# Processing Record 28 of Set 14 | muroto
# 14
# Processing Record 29 of Set 14 | kadoma
# 14
# Processing Record 30 of Set 14 | tongchuan
# 14
# Processing Record 31 of Set 14 | vaitupu
# City not found. Skipping...
# 14
# Processing Record 32 of Set 14 | pestovo
# 14
# Processing Record 33 of Set 14 | kattivakkam
# 14
# Processing Record 34 of Set 14 | naifaru
# 14
# Processing Record 35 of Set 14 | yulara
# 14
# Processing Record 36 of Set 14 | igrim
# 14
# Processing Record 37 of Set 14 | canutama
# 14
# Processing Record 38 of Set 14 | saint-augustin
# 14
# Processing Record 39 of Set 14 | poum
# 14
# Processing Record 40 of Set 14 | tiarei
# 14
# Processing Record 41 of Set 14 | ozernovskiy
# 14
# Processing Record 42 of Set 14 | dryden
# 14
# Processing Record 43 of Set 14 | fonte boa
# 14
# Processing Record 44 of Set 14 | san luis obispo
# 14
# Processing Record 45 of Set 14 | zhaotong
# 14
# Processing Record 46 of Set 14 | danjiangkou
# 14
# Processing Record 47 of Set 14 | santa barbara
# 14
# Processing Record 48 of Set 14 | morant bay
# 14
# Processing Record 49 of Set 14 | guider
# 14
# Processing Record 50 of Set 14 | hebertville
# City not found. Skipping...
# 15
# Processing Record 1 of Set 15 | kumluca
# 15
# Processing Record 2 of Set 15 | murray
# 15
# Processing Record 3 of Set 15 | chandler
# 15
# Processing Record 4 of Set 15 | kutum
# 15
# Processing Record 5 of Set 15 | mayo
# 15
# Processing Record 6 of Set 15 | toliary
# City not found. Skipping...
# 15
# Processing Record 7 of Set 15 | zalantun
# 15
# Processing Record 8 of Set 15 | aksu
# 15
# Processing Record 9 of Set 15 | azimur
# City not found. Skipping...
# 15
# Processing Record 10 of Set 15 | safranbolu
# 15
# Processing Record 11 of Set 15 | sendafa
# 15
# Processing Record 12 of Set 15 | raahe
# 15
# Processing Record 13 of Set 15 | marondera
# 15
# Processing Record 14 of Set 15 | jeremie
# 15
# Processing Record 15 of Set 15 | bahia blanca
# 15
# Processing Record 16 of Set 15 | kautokeino
# 15
# Processing Record 17 of Set 15 | akyab
# 15
# Processing Record 18 of Set 15 | ereymentau
# 15
# Processing Record 19 of Set 15 | lavumisa
# 15
# Processing Record 20 of Set 15 | mehamn
# 15
# Processing Record 21 of Set 15 | parati
# 15
# Processing Record 22 of Set 15 | opuwo
# 15
# Processing Record 23 of Set 15 | nalgonda
# 15
# Processing Record 24 of Set 15 | cascais
# 15
# Processing Record 25 of Set 15 | kenai
# 15
# Processing Record 26 of Set 15 | nishihara
# 15
# Processing Record 27 of Set 15 | belle fourche
# 15
# Processing Record 28 of Set 15 | bodden town
# 15
# Processing Record 29 of Set 15 | la rioja
# 15
# Processing Record 30 of Set 15 | halifax
# 15
# Processing Record 31 of Set 15 | laguna
# 15
# Processing Record 32 of Set 15 | mogadishu
# 15
# Processing Record 33 of Set 15 | mitu
# 15
# Processing Record 34 of Set 15 | cleethorpes
# 15
# Processing Record 35 of Set 15 | kamphaeng phet
# 15
# Processing Record 36 of Set 15 | ahuimanu
# 15
# Processing Record 37 of Set 15 | borogontsy
# 15
# Processing Record 38 of Set 15 | lavrentiya
# 15
# Processing Record 39 of Set 15 | namibe
# 15
# Processing Record 40 of Set 15 | tabou
# 15
# Processing Record 41 of Set 15 | iwanai
# 15
# Processing Record 42 of Set 15 | jaramana
# City not found. Skipping...
# 15
# Processing Record 43 of Set 15 | kargil
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Butaritari      KI   3.07  172.79     81.99        79          36
# 1    Cape Town      ZA -33.93   18.42     66.61        81           0
# 2       Atuona      PF  -9.80 -139.03     78.35        76           3
# 3        Bluff      NZ -46.60  168.33     55.80        76          98
# 4  Tuktoyaktuk      CA  69.45 -133.04     14.00        92         100
# 5        Kapaa      US  22.08 -159.32     78.78        68          20
# 6  Panalingaan      PH   8.78  117.42     83.89        73          86
# 7       Albany      US  42.60  -73.97     22.26        74          14
# 8        Vaini      TO -21.20 -175.20     80.31        70          10
# 9   Bow Island      CA  49.87 -111.37     39.58        58         100
#
#    Wind Speed Current Description
# 0       16.71          light rain
# 1        5.99           clear sky
# 2       15.95           clear sky
# 3       21.07     overcast clouds
# 4       36.82          light snow
# 5        3.00          few clouds
# 6       11.07       moderate rain
# 7        6.44          few clouds
# 8       12.75           clear sky
# 9        0.00     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv (output_data_file, index_label="City_ID")
